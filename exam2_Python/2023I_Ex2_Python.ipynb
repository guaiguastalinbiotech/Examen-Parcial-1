# %% [markdown]
# <img src="img/ikiam.png" width="500"/>
#
# # EXAMEN PARCIAL PYTHON
#
#
# ## GBI6 - BIOINFORMÁTICA
#
# **Guaigua, Stalin**
#
# **29-06-2023**

# %% [markdown]
# ## Ejercicio 0.1 [0.5 puntos]
# Realice cambios al cuaderno de jupyter:
# - Agregue el logo de la Universidad
# - Coloque sus datos personales
# - Use el terminal para crear las carpetas `results` y `data`.
# - Use el terminal y mueva `gstm.txt` que tiene un listado de accesiones de glutathione transferase a la carpeta `data`.

# %% [markdown]
# ## Ejercicio 1 [4.0 puntos]
#
# Cargue el módulo `popsimulate`, luego:
#
# 1.1. explique lo que hace cada línea de la función `build_population`, simule un ejemplo y explique el resultado.
#
# 1.2. explique lo que hace cada línea de la función `compute_frequencies`, simule un ejemplo y explique el resultado.
#
# 1.3. explique lo que hace cada línea de la función `reproduce_population`, simule un ejemplo y explique el resultado.
#
# 1.4. explique lo que hace cada línea de la función `simulate_drift`, simule un ejemplo y explique el resultado.

# %% [markdown]
# La primera función genera una lista de pares de alelos, donde cada par puede ser dominante "A" o recesivo "a". La función toma dos valores de entrada: el primero es el número de individuos "N" que se incluirán en la lista, y el segundo es "p", que representa la probabilidad de que un alelo sea "A" o "a". Como resultado, la función devuelve una lista de pares de alelos.

# %%
import scipy
from popsimulate import build_population 
build_population (100, 0.8)
# Out:
# [('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
# ...

# %% [markdown]
# La segunda función calcula las frecuencias de los diferentes genotipos en una población dada. Los genotipos son representados por pares de alelos, donde los alelos pueden ser dominantes "AA", recesivos "aa" o heterocigotos "Aa" (con diferentes combinaciones de mayúsculas y minúsculas). La función toma como entrada una población en forma de lista de pares de alelos y devuelve un diccionario que contiene las frecuencias de cada genotipo en la población. El diccionario tiene claves como "AA", "aa", "Aa" y "aA", y sus valores corresponden a las frecuencias de cada genotipo en la población.

# %%
poblacion = build_population(100,0.8)

from popsimulate import compute_frequencies 

compute_frequencies (poblacion)
# Out:
# {'AA': 72, 'aa': 4, 'Aa': 4, 'aA': 20}

# %% [markdown]
# La tercera función genera una nueva lista de pares de alelos a partir de una lista existente. En este caso, la función selecciona aleatoriamente dos alelos de posiciones diferentes en la lista de entrada. Los alelos seleccionados se combinan para formar nuevos pares de alelos en la nueva lista. La función toma como entrada una lista de pares de alelos y devuelve una nueva lista que contiene las combinaciones aleatorias de alelos seleccionados. En resumen, la función crea una variación de la lista original mediante la selección y combinación aleatoria de alelos de diferentes posiciones.

# %%
import numpy as np
from popsimulate import reproduce_population 
reproduce_population(poblacion)
# Out:
# [('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
# ...

# %% [markdown]
# La tercera función calcula el número de generaciones necesarias para alcanzar una descendencia completamente homocigota, es decir, donde todos los individuos tengan el mismo genotipo "AA" o "aa". La función comienza generando una lista de alelos utilizando la función build_population. Luego, calcula la frecuencia de los diferentes genotipos en la lista de alelos mediante la función compute_frequencies.
#
# A continuación, la función utiliza una estructura de bucle con la instrucción if para verificar si todos los individuos tienen el mismo genotipo. Si no se alcanza la homocigosis, la función genera una nueva generación de descendencia mediante la función reproduce_population y repite el proceso. Esto continúa hasta que todos los individuos en la generación sean homocigotos.
#
# La función requiere dos valores de entrada: "n", que representa el número de individuos en la población, y "p", que representa la probabilidad de que un alelo sea dominante. El resultado de la función es una lista de alelos y el número de generaciones requeridas para alcanzar la descendencia homocigota.

# %%
import numpy as np 
from popsimulate import simulate_drift 
simulate_drift(20, 0.4)
# Out:
# An allele reached fixation at generation 148
# The genotype counts are
# {'AA': 20, 'aa': 0, 'Aa': 0, 'aA': 0}
# (148, {'AA': 20, 'aa': 0, 'Aa': 0, 'aA': 0})

# %% [markdown]
# ## Ejercicio 2 [5.0 puntos]
#
# Cree el modulo `glutransferase.py` y genere las siguientes funciones:
#
# 2.1. `source` que se conecte al `NCBI` y `Nucleotide` para extraer el nombre del organismo fuente y que cuente la frecuencia de cada especie. Guarde el resultado en `results/source.csv`
#
# 2.2. `sequences` que se conecte al `NCBI` y `Nucleotide` para extraer la secuencia de ADN, que se realice la traducción y separación de péptidos. Asegurarse que los péptidos empiezan en metionina. Luego calcule `molecular weight` e `instability index`. Genere un `joinplot` utilizando los valores de peso molecular e índice de estabilidad. Edite color, tamaño y tipo de puntos, asimismo etiquete adecuadamente el título y los ejes. Guarde los resultados en `results/glupeptides.csv` y `results/glupeptides.png`.
#
# **No escriba las funciones en este cuaderno de jupyter**
#
# 2.3. Use la lista de accesiones en `data/gstm.txt`, cargue el módulo `glutransferase` y ejecute las dos funciones.

# %%
from Bio import Entrez
from Bio import SeqIO  
from Bio.SeqUtils.ProtParam import ProteinAnalysis
import collections
import pandas as pd  
import re
import matplotlib.pyplot as plt 
from glutransferase import source
from glutransferase import sequences

# %%
from Bio import Entrez
from glutransferase import source
from glutransferase import sequences

# %%
source("data/gstm.txt")
# Out:
#                                               Especie  Frecuencia
# 0                                Homo sapiens (human)           3
# 1                           Rattus rattus (black rat)           1
# 2                                            Zea mays           1
# 3                               Glycine max (soybean)           2
# 4                     Triticum aestivum (bread wheat)           6
# 5                              Carica papaya (papaya)           1
# 6         Todarodes pacificus (Japanese flying squid)           1
# 7                                 Onchocerca volvulus           1
# 8   Mus musculus domesticus (western European hous...           1
# 9                             Gallus gallus (chicken)           1
# 10                                  Chlamys islandica           1
# 11                 Arabidopsis thaliana (thale cress)           2
# 12                             Alopecurus myosuroides           7
# ...

# %%
def sequences(data): 
    file = open(data, "r")
    secuencias  = open("data/sequences.gb", "w")
    for linea in file: 
        Entrez.email = "stalin.guaigua@est.ikiam.edu.ec"
        handle=Entrez.efetch(db="nucleotide" ,id=linea ,rettype="gb", retmode="text")
        data=(handle.read())
        secuencias.write(data) 
    genbank = list(SeqIO.parse("data/sequences.gb", "genbank"))
    MW = []
    indice = []
    for i in range(len(genbank)):
        seq_peptide = genbank[i].seq.translate()
        if seq_peptide[0] == "M" and not re.search(re.escape("*"), str(seq_peptide[0:-1])):
            temp = ProteinAnalysis(seq_peptide[0:-1])
            MW.append(temp.molecular_weight())
            indice.append(temp.instability_index())
    df = pd.DataFrame() 
    df ["Peso Molecular"] = MW 
    df ["Indice de inestabilidad"] = indice
    df.to_csv("results/glupeptides.csv")  
    plt.plot(MW, indice, 'x', color='yellow')
    plt.xlabel('Peso Molecular [Daltons]', fontsize=12)
    plt.ylabel('Indice de Inestabilidad', fontsize=12)
    plt.savefig("results/glupeptides.png")

# %%
sequences("data/gstm.txt")
# Out:
# /home/jpramosg/.local/lib/python3.11/site-packages/Bio/Seq.py:2804: BiopythonWarning: Partial codon, len(sequence) not a multiple of three. Explicitly trim the sequence or add trailing N before translation. This may become an error in future.
#   warnings.warn(

# %% [markdown]
# ## Ejercicio 0.2 [0.5 puntos]
#
#
# 1. Cree un archivo ```Readme.md``` que debe tener lo siguiente:
# - Datos personales
# - Características del computador
# - Versión de Python/Anaconda y de cada uno de los módulos/paquetes y utilizados
# - Explicación de la data utilizada
#
# 2. Realice al menos 1 control de la versión (commits) por cada ejercicio (del 1 al 5), con un mensaje que inicie como:
#
# ```sh
# Carlitos Alimaña ha realizado el ejercicio 1.1
# ```
# ```sh
# Carlitos Alimaña ha realizado el ejercicio 2.1
# ```
# ```sh
# ...
# ```
